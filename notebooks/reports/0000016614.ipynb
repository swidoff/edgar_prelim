# %%
from edgar_prelim import *
import pandas as pd
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline
pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 500)

# %%
cik='0000004962'

# %%
# Parameters
cik = "0000016614"

# %% [markdown]
# # Company

# %%
cik_df = pd.read_sql(text("select cik, sic, sic_description, company_name, ticker from cik where cik = :cik").bindparams(cik=cik), prelim_engine)
cik_df.rename({'cik': 'CIK', 'sic': 'SIC', 'sic_description': 'Description', 'company_name': 'Name', 'ticker': 'Ticker'}, axis=1).T.rename({0: ''}, axis=1)
# Out:
#
# CIK                                             0000016614
# SIC                                                   6036
# Description  SAVINGS INSTITUTIONS, NOT FEDERALLY CHARTERED
# Name                                  CAMCO FINANCIAL CORP
# Ticker                                                CAFI

# %%
prelims = query_prelims(cik)

# %% [markdown]
# # Summary Statistics

# %%
prelims.groupby('item').item_value.describe()
# Out:
#                            count         mean           std          min  \
# item
# book value per share        25.0         8.13  3.015442e+00         4.49
# interest income             25.0  10984040.00  3.642435e+06   6858000.00
# net income                  25.0    162480.00  3.781505e+06 -11809000.00
# net interest income         25.0   6599760.00  7.594572e+05   5399000.00
# provision for loan losses   25.0   1453800.00  4.486196e+06  -1455000.00
#
#                                   25%         50%          75%          max
# item
# book value per share             6.26         6.4        11.98        12.37
# interest income            7936000.00  10109000.0  15157000.00  16823000.00
# net income                  413000.00    727000.0   1347000.00   6154000.00
# net interest income        5985000.00   6436000.0   7378000.00   8099000.00
# provision for loan losses   120000.00    360000.0    894000.00  19914000.00

# %% [markdown]
# # Plots

# %%
_ = prelims.set_index('filing_date').pivot(columns='item', values='item_value').fillna(method="ffill").plot(subplots=True, layout=(2, 3), figsize=(20, 10), sharex=False)

# %% [markdown]
# # Quality

# %%
validate_prelims(prelims)
# Out:
#                                                            period msg_type  \
# cik        item
# 0000016614 book value per share       2007Q4 to 2009Q3: 8 periods  missing
#            interest income            2007Q4 to 2009Q3: 8 periods  missing
#            net income                 2007Q4 to 2009Q3: 8 periods  missing
#            net interest income        2007Q4 to 2009Q3: 8 periods  missing
#            provision for loan losses  2007Q4 to 2009Q3: 8 periods  missing
#            provision for loan losses                       2013Q2  missing
#            total revenue                                     None    empty
#
#                                                  message
# cik        item
# 0000016614 book value per share           Missing period
#            interest income                Missing period
#            net income                     Missing period
#            net interest income            Missing period
#            provision for loan losses      Missing period
#            provision for loan losses      Missing period
#            total revenue              No values for item

# %% [markdown]
# # Data

# %%
def make_clickable(val: str) -> str: 
    if isinstance(val, str):
        name, url = val.split('#')
        return f'<a href="{url}">{name}</a>'
    else:
        return ''

(prelims
 .assign(fiscal_period = prelims.fiscal_period.str.cat(prelims.filing_href, sep='#'), filing_date = prelims.filing_date.map(lambda d: d.strftime('%Y-%m-%d')))
 .loc[:, ['filing_date', 'fiscal_period', 'item', 'item_value', 'src_table', 'src_row', 'src_column', 'src_value', 'src_units']]
 .set_index(['filing_date', 'item'])
 .style.format({'fiscal_period': make_clickable})
)
# Out:
# <style  type="text/css" >
# </style><table id="T_096ca7c2_8240_11e9_a060_34e12d8376c5" ><thead>    <tr>        <th class="blank" ></th>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >fiscal_period</th>        <th class="col_heading level0 col1" >item_value</th>        <th class="col_heading level0 col2" >src_table</th>        <th class="col_heading level0 col3" >src_row</th>        <th class="col_heading level0 col4" >src_column</th>        <th class="col_heading level0 col5" >src_value</th>        <th class="col_heading level0 col6" >src_units</th>    </tr>    <tr>        <th class="index_name level0" >filing_date</th>        <th class="index_name level1" >item</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T
#                         <td id="T_096ca7c2_8240_11e9_a060_34e12d8376c5row3_col0" class="data row3 col0" ><a href="https://www.sec.gov/Archives/edgar/data/16614/000095015206000471/0000950152-06-000471-index.htm">2005Q4</a></td>
#                         <td id="T_096ca7c2_8240_11e9_a060_34e12d8376c5row3_col1" class="data row3 col1" >8.099e+06</td>
#                         <td id="T_096ca7c2_8240_11e9_a060_34e12d8376c5row3_col2" class="data row3 col2" >Condensed Consolidated Statements of Earnings</td>
#                         <td id="T_096ca7c2_8240_11e9_a060_34e12d8376c5row3_col3" class="data row3 col3" >Net Interest Income</td>
#                         <td id="T_096ca7c2_8240_11e9_a060_34e12d8376c5row3_col4" class="data row3 col4" >3 Months Ended 12/31/05</td>
#                         <td id="T_096ca7c2_8240_11e9_a060_34e12d8376c5row3_col5" class="data row3 col5" >8099</td>
#                         <td id="T_096ca7c2_8240_11e9_a060_34e12d8376c5row3_col6" class="data row3 col6" >(In thousands, except for per share data and shares outstanding)</td>
#             </tr>
#             <tr>
#                                 <th id="T_096ca7c2_8240_11e9_a060_34e12d8376c5level1_row4" class="row_heading level1 row4" >provision for loan losses</th>
#                         <td id="T_096ca7c2_8240_11e9_a060_34e12d8376c5row4_col0" class="data row4 col0" ><a href="https://www.sec.gov/Archives/edgar/data/16614/000095015206000471/0000950152-06-000471-index.htm">2005Q4</a></td>
#                         <td id="T_096ca7c2_8240_11e9_a060_34e12d8376c5row4_col1" class="data row4 col1" >520000</td>
#                         <td id="T_096ca7c2_8240_11e9_a060_34e12d8376c5row4_col2" class="data row4 col2" >Condensed Consolidated Statements of Earnings</td>
#                         <td id="T_096ca7c2_8240_11e9_a060_34e12d8376c5row4_col3" class="data row4 col3" >Provision for Losses on Loans</td>
#                         <td id="T_096ca7c2_8240_11e9_a060_34e12d8376c5row4_col4" class="data row4 col4" >3 Months Ended 12/31/05</td>
#                         <td id="T_096ca7c2_8240_11e9_a060_34e12d8376c5row4_col5" class="data row4 col5" >520</td>
#                         <td id="T_096ca7c2_8240_11e9_a060_34e12d8376c5row4_col6" class="data row4 col6" >(In thousands, except for per share data and shares outstanding)</td>
#             </tr>
#             <tr>
#                         <th id="T_096ca7c2_8240_11e9_a060_34e12d8376c5level0_row5" class="row_heading level0 row5" rowspan=5>2006-04-28</th>
#                         <th id="T_096ca7c2_8240_11e9_a060_34e12d8376c5level1_row5" class="row_heading level1 row5" >book value per share</th>
#                         <td id="T_096ca7c2_8240_11e9_a060_34e12d8376c5row5_col0" class="data row5 col0" ><a href="https://www.sec.gov/Archives/edgar/data/16614/000095012806000037/0000950128-06-000037-index.htm">2006Q1</a></td>
#                         <td id="T_096ca7c2_8240_11e9_a060_34e12d8376c5row5_col1" class="data row5 col1" >11.97</td>
#                         <td id="T_096ca7c2_8240

# %%
#discard_prelim(cik, date(2019, 12, 31))
#force_reload_prelim(cik, date(2019, 12, 31), delete_filings=False)
#force_reload_prelim_between(cik,  start=date(2002, 6, 1), end=date(2019, 12, 31), delete_filings=False)

# %%
#d = date(2018, 10, 29)
#extract_prelim_statements(cik, start=d, end=d)

# %%
#d = date(2019, 4, 22)
#filings = query_edgar_for_filings(cik, "8-K", start=d, end=d, require_xbrl=False)
#report = query_edgar_for_submission_text(filings[0].href)
#submission = load_submission(report.href)
#tables = list(parse_tables(submission))
#items_from_tables(tables)

# %%
#widget = query_prelims_for_override(cik, filing_date='2006-01-27', item=None)
#widget

# %%
#widget.save()
